# %%
import qsharp

from Operations import LocalCnotSim, VerticalMoveSim, HorizontalMoveSim, DiagonalSwapSim

# %who
# print(qsharp.get_available_operations())

# %%
LocalCnotSim.simulate(ctl=False, tgt=False)
LocalCnotSim.simulate(ctl=False, tgt=True)
LocalCnotSim.simulate(ctl=True, tgt=False)
LocalCnotSim.simulate(ctl=True, tgt=True)
# Out:
# Got ctl=Zero, tgt=Zero
# Got ctl=Zero, tgt=One
# Got ctl=One, tgt=One
# Got ctl=One, tgt=Zero
# ()

# %%
# VerticalMoveSim.simulate(frm=False, to=False)
# VerticalMoveSim.simulate(frm=False, to=True)
# VerticalMoveSim.simulate(frm=True, to=False)
# VerticalMoveSim.simulate(frm=True, to=True)

# %%
# HorizontalMoveSim.simulate(frm=False, to=False)
# HorizontalMoveSim.simulate(frm=False, to=True)
# HorizontalMoveSim.simulate(frm=True, to=False)
# HorizontalMoveSim.simulate(frm=True, to=True)

# %%
# DiagonalSwapSim.simulate(tl=False, br=False)
# DiagonalSwapSim.simulate(tl=False, br=True)
# DiagonalSwapSim.simulate(tl=True, br=False)
# DiagonalSwapSim.simulate(tl=True, br=True)

# %%
qir = LocalCnotSim.as_qir()
# Out:
# No such magic command %qir.
# Possibly similar magic commands:
# - %who
# - %config
# - %debug
# To get a list of all available magic commands, run %lsmagic, or visit https://docs.microsoft.com/qsharp/api/iqsharp-magic/.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\baehl\workspaces\surface-code-compilation\test\test.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/baehl/workspaces/surface-code-compilation/test/test.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> qir = LocalCnotSim.as_qir()
#
# File c:\Users\baehl\anaconda3\envs\surface-code-compilation\lib\site-packages\qsharp\loader.py:134, in QSharpCallable.as_qir(self)
#     129 """
#     130 Returns the QIR representation of the callable,
#     131 assuming the callable is an entry point.
#     132 """
#     133 data = qsharp.client.compile_to_qir(self)
# --> 134 return data['Text']
#
# ...

# %%
print(qir)
# Out:
# ; ModuleID = '/tmp/tmp4WtyVD.bc'
#
# %Qubit = type opaque
# %Result = type opaque
# %String = type opaque
# %Array = type opaque
# %Tuple = type opaque
#
# @0 = internal constant [36 x i8] c"Qubit in invalid state. Expecting: \00"
# @1 = internal constant [9 x i8] c"Got ctl=\00"
# @2 = internal constant [7 x i8] c", tgt=\00"
# @3 = internal constant [3 x i8] c"()\00"
#
# define internal void @ENTRYPOINT__LocalCnotSim__body(i1 %ctl, i1 %tgt) {
# entry:
#   call void @Operations__LocalCnotSim__body(i1 %ctl, i1 %tgt)
#   ret void
# }
#
# define internal void @Operations__LocalCnotSim__body(i1 %ctl, i1 %tgt) {
# entry:
#   %qctl = call %Qubit* @__quantum__rt__qubit_allocate()
#   %qtgt = call %Qubit* @__quantum__rt__qubit_allocate()
#   %qhlp = call %Qubit* @__quantum__rt__qubit_allocate()
#   call void @Operations____QsRef5__PrepareZ____body(%Qubit* %qctl)
#   call void @Operations____QsRef5__PrepareZ____body(%Qubit* %qtgt)
#   br i1 %ctl, label %then0__1, label %continue__1
#
# ...
